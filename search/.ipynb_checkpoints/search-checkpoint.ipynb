# %%
import subprocess
import numpy as np
import glob
import os
import time
import pandas as pd
from pathlib import Path
import shutil

# %%
def make_data_path(window_size: float) -> str:
    return f"new_data/new_obsids_w{window_size:.1f}"



DEFAULT_DATA_PATH = "new_data"  # Folder for downloaded obsids 

WINDOW_SIZES = [0.1, 0.2, 0.4, 0.8]  # The window size to use for the search

VERBOSE = 1  # Level of verbosity for the search functions

FILENAMES = [  # List of filenames to search
    #'obsid_lists/obsids_b+10_250107.csv',
    'obsid_lists/obsids_b-10_250107.csv',
    #'obsid_lists/obsids_b+10_250107_subset.csv'
]



def count_detections_for_obsid(detections_path: str, obsid: str) -> int:
    """
    Count how many lines in detections file belong to this obsid.
    Works even if there is no header; assumes obsid is first token per line.
    """
    p = Path(detections_path)
    if not p.exists():
        return 0
    count = 0
    with p.open() as f:
        for line in f:
            s = line.strip()
            if not s:
                continue
            # skip header-like lines if any
            if s.lower().startswith("obs") or s.lower().startswith("obsid"):
                continue
            first = s.split()[0]
            if first == str(obsid):
                count += 1
    return count

def delete_obsid_folder(obsid: str, data_path: str, verbose: int = 0) -> None:
    obs_dir = Path(data_path) / str(obsid)
    if obs_dir.exists():
        if verbose:
            print(f"\tNo detections → deleting {obs_dir}")
        shutil.rmtree(obs_dir, ignore_errors=True)


def read_obsids(filenames: list[str], columns: list[str] = ['Obs ID', 'Public Release Date']) -> pd.DataFrame:
    """
    ## Read obsids from a list of files.

    ### Args:
        filenames `list[str]`: List of filenames to read obsids from.
        columns `list[str]` (optional): Defaults to `['Obs ID', 'Public Release Date']`. Columns to read from the files.

    ### Returns:
        `pd.DataFrame`: DataFrame with the obsids.
    """
    obsids = pd.DataFrame(columns=columns)
    for filename in filenames:
        inter_obsids = pd.read_csv(
            filename, header=0, dtype=str, usecols=columns)
        obsids = pd.concat([obsids, inter_obsids], ignore_index=True)
    return obsids


def download_data(obsid: str, verbose: int = 0, data_path: str = DEFAULT_DATA_PATH):
    """
    ## Download data for a given obsid.

    ### Args:
        obsid `str`: Obsid to download data for.
        verbose `int` (optional): Defaults to `0`. Level of verbosity.
        data_path `str` (optional): Defaults to `DEFAULT_DATA_PATH`. Path where all downloaded data is stored.
    """
    if verbose > 0:
        print(f"\tDownloading")
        start_time = time.perf_counter()

    current_path = os.getcwd()
    os.chdir(f"{data_path}")

    command = f'download_chandra_obsid {obsid} evt2,fov,asol,bpix,msk'
    proc = subprocess.run(command, shell=True)

    command = f'cp {obsid}/primary/* {obsid}/'
    proc = subprocess.run(command, shell=True)

    command = f'gunzip {obsid}/*.gz'
    proc = subprocess.run(command, shell=True)

    os.chdir(f"{current_path}")

    if verbose > 0:
        end_time = time.perf_counter()
        print(f"\tFinished downloading")
        print(f"\tDownload time: {end_time - start_time:.0f} seconds")

def process_data(obsid: str, verbose: int = 0, data_path: str = DEFAULT_DATA_PATH) -> bool:
    """
    ## Process the data for a given obsid.
    """
    if verbose > 0:
        print(f"\tProcessing")
        start_time = time.perf_counter()

    current_path = os.getcwd()

    try:
        os.chdir(f"{data_path}/{obsid}/")
    except FileNotFoundError:
        if verbose > 0:
            print(f"\tNo data found")
        return False

    event_file = glob.glob('*evt2.fits*', recursive=True)
    fov_file = glob.glob('*N*fov1.fits*', recursive=True)

    if not event_file or not fov_file:
        if verbose > 0:
            print("\tMissing event or fov file")
        os.chdir(current_path)
        return False

    # mask 
    command = f'dmcopy "{fov_file[0]}" s3.fov clobber=yes'
    subprocess.run(command, shell=True)

    command = f'dmcopy "{event_file[0]}[sky=region(s3.fov)]" 578_evt2_filtered.fits clobber=yes'
    subprocess.run(command, shell=True)

    # fluximage 
    t = time.perf_counter()
    command = 'fluximage 578_evt2_filtered.fits outroot=s3 bands=broad binsize=2 clobber=yes'
    subprocess.run(command, shell=True)
    print("fluximage:", time.perf_counter() - t, "s")

    # mkpsfmap
    t = time.perf_counter()
    command = 'mkpsfmap s3_broad_thresh.img outfile=s3_psfmap.fits energy=1.4967 ecf=0.393 clobber=yes'
    subprocess.run(command, shell=True)
    print("mkpsfmap:", time.perf_counter() - t, "s")

    # wavdetect for 2 scales
    t = time.perf_counter()
    full_scales = "1 2 4 8 16 32"
    reduced_scales = "1 2 4 8 16"

    print(f"\tRunning wavdetect with full scales: {full_scales}")
    proc = subprocess.run(
        f'wavdetect infile=s3_broad_thresh.img '
        f'psffile=s3_psfmap.fits '
        f'expfile=s3_broad_thresh.expmap '
        f'outfile=s3_expmap_src.fits '
        f'scellfile=s3_expmap_scell.fits '
        f'imagefile=s3_expmap_imgfile.fits '
        f'defnbkgfile=s3_expmap_nbgd.fits '
        f'scales="{full_scales}" sigthresh=1e-6 clobber=yes',
        shell=True, capture_output=True, text=True
    )

    # check for scale-related failure
    if "too big for dataset size" in proc.stderr or "wtransform failed" in proc.stderr:
        print("\t⚠️ wavdetect failed at large scale; retrying with smaller scales.")
        proc = subprocess.run(
            f'wavdetect infile=s3_broad_thresh.img '
            f'psffile=s3_psfmap.fits '
            f'expfile=s3_broad_thresh.expmap '
            f'outfile=s3_expmap_src.fits '
            f'scellfile=s3_expmap_scell.fits '
            f'imagefile=s3_expmap_imgfile.fits '
            f'defnbkgfile=s3_expmap_nbgd.fits '
            f'scales="{reduced_scales}" sigthresh=1e-6 clobber=yes',
            shell=True, capture_output=True, text=True
        )

    print("wavdetect:", time.perf_counter() - t, "s")

    # return to main path 
    os.chdir(current_path)

    if verbose > 0:
        end_time = time.perf_counter()
        print(f"\tFinished processing")
        print(f"\tProcessing time: {end_time - start_time:.0f} seconds")

    return True


def search_data(obsid: str, window_size: float = 20.0, verbose: int = 0, data_path: str = DEFAULT_DATA_PATH):
    if verbose > 0:
        print(f"\tSearching")
        start_time = time.perf_counter()

    current_path = os.getcwd()

    command = f"cp auxiliary/search_algorithm.py {data_path}/{obsid}/"
    subprocess.run(command, shell=True)

    os.chdir(f"{data_path}/{obsid}/")

    t = time.perf_counter()
    command = f"python search_algorithm.py {current_path} {window_size} {verbose}"
    proc = subprocess.run(command, shell=True, stdout=subprocess.PIPE)
    print("search_algorithm.py:", time.perf_counter() - t, "s")

    if verbose > 1:
        print(proc.stdout)

    os.chdir(f"{current_path}")

    if verbose > 0:
        end_time = time.perf_counter()
        print(f'\tFinished searching')
        print(f'\tSearching time: {end_time - start_time:.0f} seconds')

def pipeline(obsid: str, window_size: float = 20.0, verbose: int = 0, data_path: str = DEFAULT_DATA_PATH) -> None:
    """
    ## Pipeline to download, process and search data for a given obsid.
    """
    if verbose > 0:
        print(f'Starting obsid: {obsid}')
        start_time = time.perf_counter()

    # check analysed file 
    analysed_file = f'output/analysed_w{window_size:.1f}_forward.txt'
    try:
        analysed = pd.read_csv(analysed_file, header=0, sep=r"\s+", dtype=str)
        already_analysed = str(obsid) in set(analysed['ObsId'].astype(str).values)

        if verbose > 1:
            print(f"\tChecking analysed file: {analysed_file}")
            print(f"\tFirst few ObsIds: {analysed['ObsId'].head().tolist()}")
    except FileNotFoundError:
        analysed = None
        already_analysed = False

    if already_analysed:
        if verbose > 0:
            print(f'\tObsid {obsid} already searched')
        if verbose > 0:
            end_time = time.perf_counter()
            print(f'Finished obsid: {obsid}')
            print(f'Time: {end_time - start_time:.0f} seconds')
        return  # stop early, nothing else to do

    # download data if not already downloaded
    os.makedirs(data_path, exist_ok=True)
    dirs = os.listdir(f"{data_path}/")
    if obsid in dirs:
        if verbose > 0:
            print(f'\tObsid data already downloaded')
    else:
        download_data(obsid, verbose, data_path)
        if not process_data(obsid, verbose, data_path):
            return  # skip if processing failed

    # count detections before search
    detections_file = f'output/detections_w{window_size:.1f}_forward.txt'
    before = count_detections_for_obsid(detections_file, obsid)

    # run search
    search_data(obsid, window_size, verbose, data_path)

    # count detections after search
    after = count_detections_for_obsid(detections_file, obsid)
    new_hits = after - before

    # cleanup if no detections
    try:
        analysed = pd.read_csv(analysed_file, header=0, sep=r"\s+", dtype=str)
        is_analysed_now = str(obsid) in set(analysed['ObsId'].astype(str).values)
    except Exception:
        is_analysed_now = False

    if is_analysed_now and new_hits == 0:
        delete_obsid_folder(obsid, data_path, verbose=verbose)

    if verbose > 0:
        end_time = time.perf_counter()
        print(f'Finished obsid: {obsid}')
        print(f'Time: {end_time - start_time:.0f} seconds')


def start_search(filenames: list, window_size: float = 20.0, data_path: str = DEFAULT_DATA_PATH, limit_observations: bool = False, verbose: int = 0) -> None:
    """
    ## Start the search for a list of filenames.

    ### Args:
        filenames `list`: List of filenames to search.
        window_size `float` (optional): Defaults to `20.0`. Window size to use for the search.
        data_path `str` (optional): Defaults to `DEFAULT_DATA_PATH`. Path where all downloaded data is stored.
        limit_observations `bool` (optional): Defaults to `False`. Whether to only search observations with an exposure time longer than window_size.
        verbose `int` (optional): Defaults to `0`. Level of verbosity.
    """
    obsids = read_obsids(filenames, ['Obs ID', 'Exposure'])
    obsids['Exposure'] = obsids['Exposure'].astype(float)

    if limit_observations:
        obsids = obsids[obsids['Exposure'] > window_size]

    for i, (index, obsid) in enumerate(obsids.iterrows()):
        print(f"progress: {(i+1)/len(obsids) * 100:.2f}%")
        pipeline(obsid['Obs ID'], window_size, verbose, data_path)


def pipeline_multiwindow(
    obsid: str,
    window_sizes: list,
    verbose: int = 0,
    data_path_base: str = "new_data"
) -> None:
    """
    For running the pipeline for one ObsID across multiple window sizes,
    """

    if verbose > 0:
        print(f"Starting ObsID {obsid} for windows {window_sizes}")

    #  check if all windows already analysed or detected
    all_done = True
    for w in window_sizes:
        analysed_file = f"output/analysed_w{w:.1f}_forward.txt"
        detections_file = f"output/detections_w{w:.1f}_forward.txt"

        in_analysed = False
        in_detections = False

        # check analysed file
        if Path(analysed_file).exists():
            analysed = pd.read_csv(
                analysed_file,
                sep=r"\s+",
                dtype=str,
                header=None,
                names=["ObsId"],
                engine="python"
            )
            if str(obsid) in analysed["ObsId"].astype(str).values:
                in_analysed = True

        # check detections file
        if Path(detections_file).exists():
            if count_detections_for_obsid(detections_file, obsid) > 0:
                in_detections = True

        if not (in_analysed or in_detections):
            all_done = False
            break

    if all_done:
        if verbose > 0:
            print(f"\tObsID {obsid} already analysed/detected for all windows, skipping")
        return

    # download + process if not already present
    obsid_path = Path(data_path_base) / str(obsid)
    if not obsid_path.exists():
        download_data(obsid, verbose, data_path_base)
        if not process_data(obsid, verbose, data_path_base):
            return
    else:
        if verbose > 0:
            print(f"\tObsID {obsid} already downloaded/processed")

    # run searches only for windows not already analysed/detected
    for w in window_sizes:
        analysed_file = f"output/analysed_w{w:.1f}_forward.txt"
        detections_file = f"output/detections_w{w:.1f}_forward.txt"

        in_analysed = False
        in_detections = False

        # check analysed file
        if Path(analysed_file).exists():
            analysed = pd.read_csv(
                analysed_file,
                sep=r"\s+",
                dtype=str,
                header=None,
                names=["ObsId"],
                engine="python"
            )
            if str(obsid) in analysed["ObsId"].astype(str).values:
                in_analysed = True

        # check detections file
        if Path(detections_file).exists():
            if count_detections_for_obsid(detections_file, obsid) > 0:
                in_detections = True

        if in_analysed or in_detections:
            if verbose > 0:
                print(f"\tWindow {w:.1f} ks: already analysed/detected, skipping")
            continue

        before = count_detections_for_obsid(detections_file, obsid)
        search_data(obsid, window_size=w, verbose=verbose, data_path=data_path_base)
        after = count_detections_for_obsid(detections_file, obsid)
        new_hits = after - before

        if verbose > 0:
            print(f"\tWindow {w:.1f} ks: {new_hits} new detections")

    # cleanup if no detections in any window
    total_hits = 0
    for w in window_sizes:
        detections_file = f"output/detections_w{w:.1f}_forward.txt"
        total_hits += count_detections_for_obsid(detections_file, obsid)

    if total_hits == 0:
        delete_obsid_folder(obsid, data_path_base, verbose=verbose)


        
 
if __name__ == "__main__":
    obsids = read_obsids(FILENAMES, ["Obs ID", "Exposure"])
    obsids = obsids["Obs ID"].astype(str).tolist()

    for i, obsid in enumerate(obsids):
        print(f"\n=== {i+1}/{len(obsids)}: Running ObsID {obsid} ===")
        pipeline_multiwindow(obsid, WINDOW_SIZES, verbose=VERBOSE, data_path_base="new_data")

    #pipeline_multiwindow("13825", WINDOW_SIZES, verbose=VERBOSE, data_path_base="new_data")
# Out:
# === 1/4750: Running ObsID 1 ===
# Starting ObsID 1 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 1 already analysed/detected for all windows, skipping
#
# === 2/4750: Running ObsID 1482 ===
# Starting ObsID 1482 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 1482 already analysed/detected for all windows, skipping
#
# === 3/4750: Running ObsID 583 ===
# Starting ObsID 583 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 583 already analysed/detected for all windows, skipping
#
# === 4/4750: Running ObsID 960 ===
# Starting ObsID 960 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 960 already analysed/detected for all windows, skipping
#
# === 5/4750: Running ObsID 1463 ===
# Starting ObsID 1463 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 1463 already analysed/detected for all windows, skipping
#
# === 6/4750: Running ObsID 2518 ===
# Starting ObsID 2518 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 2518 already analysed/detected for all windows, skipping
#
# === 7/4750: Running ObsID 12315 ===
# Starting ObsID 12315 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 12315 already analysed/detected for all windows, skipping
#
# === 8/4750: Running ObsID 12316 ===
# Starting ObsID 12316 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 12316 already analysed/detected for all windows, skipping
#
# === 9/4750: Running ObsID 17703 ===
# Starting ObsID 17703 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 17703 already analysed/detected for all windows, skipping
#
# === 10/4750: Running ObsID 17708 ===
# Starting ObsID 17708 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 17708 already analysed/detected for all windows, skipping
#
# === 11/4750: Running ObsID 17709 ===
# Starting ObsID 17709 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 17709 already analysed/detected for all windows, skipping
#
# === 12/4750: Running ObsID 20275 ===
# Starting ObsID 20275 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 20275 already analysed/detected for all windows, skipping
#
# === 13/4750: Running ObsID 21981 ===
# Starting ObsID 21981 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 21981 already analysed/detected for all windows, skipping
#
# === 14/4750: Running ObsID 21982 ===
# Starting ObsID 21982 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 21982 already analysed/detected for all windows, skipping
#
# === 15/4750: Running ObsID 21993 ===
# Starting ObsID 21993 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 21993 already analysed/detected for all windows, skipping
#
# === 16/4750: Running ObsID 22291 ===
# Starting ObsID 22291 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 22291 already analysed/detected for all windows, skipping
#
# === 17/4750: Running ObsID 22292 ===
# Starting ObsID 22292 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 22292 already analysed/detected for all windows, skipping
#
# === 18/4750: Running ObsID 22293 ===
# Starting ObsID 22293 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 22293 already analysed/detected for all windows, skipping
#
# === 19/4750: Running ObsID 25103 ===
# Starting ObsID 25103 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 25103 already analysed/detected for all windows, skipping
#
# === 20/4750: Running ObsID 25104 ===
# Starting ObsID 25104 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 25104 already analysed/detected for all windows, skipping
#
# === 21/4750: Running ObsID 25105 ===
# Starting ObsID 25105 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 25105 already analysed/detected for all windows, skipping
#
# === 22/4750: Running ObsID 25106 ===
# Starting ObsID 25106 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 25106 already analysed/detected for all windows, skipping
#
# === 23/4750: Running ObsID 25993 ===
# Starting ObsID 25993 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 25993 already analysed/detected for all windows, skipping
#
# === 24/4750: Running ObsID 27476 ===
# Starting ObsID 27476 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 27476 already analysed/detected for all windows, skipping
#
# === 25/4750: Running ObsID 27477 ===
# Starting ObsID 27477 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 27477 already analysed/detected for all windows, skipping
#
# === 26/4750: Running ObsID 25994 ===
# Starting ObsID 25994 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 25994 already analysed/detected for all windows, skipping
#
# === 27/4750: Running ObsID 27703 ===
# Starting ObsID 27703 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 27703 already analysed/detected for all windows, skipping
#
# === 28/4750: Running ObsID 25995 ===
# Starting ObsID 25995 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 25995 already analysed/detected for all windows, skipping
#
# === 29/4750: Running ObsID 27882 ===
# Starting ObsID 27882 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 27882 already analysed/detected for all windows, skipping
#
# === 30/4750: Running ObsID 13 ===
# Starting ObsID 13 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 13 already analysed/detected for all windows, skipping
#
# === 31/4750: Running ObsID 366 ===
# Starting ObsID 366 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 366 already analysed/detected for all windows, skipping
#
# === 32/4750: Running ObsID 18 ===
# Starting ObsID 18 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 18 already analysed/detected for all windows, skipping
#
# === 33/4750: Running ObsID 1522 ===
# Starting ObsID 1522 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 1522 already downloaded/processed
# 	Searching
# search_algorithm.py: 0.9528255895711482 s
# 	Finished searching
# 	Searching time: 1 seconds
# 	Window 0.1 ks: 0 new detections
# 	Window 0.2 ks: already analysed/detected, skipping
# 	Searching
# search_algorithm.py: 0.6164392428472638 s
# 	Finished searching
# 	Searching time: 1 seconds
# 	Window 0.4 ks: 0 new detections
# 	Searching
# search_algorithm.py: 1.1647371863946319 s
# 	Finished searching
# 	Searching time: 1 seconds
# 	Window 0.8 ks: 0 new detections
#
# === 34/4750: Running ObsID 19 ===
# Starting ObsID 19 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 19 already analysed/detected for all windows, skipping
#
# === 35/4750: Running ObsID 21 ===
# Starting ObsID 21 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 21 already analysed/detected for all windows, skipping
#
# === 36/4750: Running ObsID 606 ===
# Starting ObsID 606 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 606 already analysed/detected for all windows, skipping
#
# === 37/4750: Running ObsID 624 ===
# Starting ObsID 624 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 624 already analysed/detected for all windows, skipping
#
# === 38/4750: Running ObsID 631 ===
# Starting ObsID 631 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 631 already analysed/detected for all windows, skipping
#
# === 39/4750: Running ObsID 1480 ===
# Starting ObsID 1480 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 1480 already analysed/detected for all windows, skipping
#
# === 40/4750: Running ObsID 634 ===
# Starting ObsID 634 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 634 already analysed/detected for all windows, skipping
#
# === 41/4750: Running ObsID 642 ===
# Starting ObsID 642 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 642 already analysed/detected for all windows, skipping
#
# === 42/4750: Running ObsID 62520 ===
# Starting ObsID 62520 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 62520 already analysed/detected for all windows, skipping
#
# === 43/4750: Running ObsID 603 ===
# Starting ObsID 603 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 603 already analysed/detected for all windows, skipping
#
# === 44/4750: Running ObsID 1866 ===
# Starting ObsID 1866 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 1866 already analysed/detected for all windows, skipping
#
# === 45/4750: Running ObsID 1867 ===
# Starting ObsID 1867 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 1867 already analysed/detected for all windows, skipping
#
# === 46/4750: Running ObsID 1872 ===
# Starting ObsID 1872 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 1872 already analysed/detected for all windows, skipping
#
# === 47/4750: Running ObsID 1878 ===
# Starting ObsID 1878 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 1878 already analysed/detected for all windows, skipping
#
# === 48/4750: Running ObsID 1881 ===
# Starting ObsID 1881 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 1881 already analysed/detected for all windows, skipping
#
# === 49/4750: Running ObsID 1882 ===
# Starting ObsID 1882 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 1882 already analysed/detected for all windows, skipping
#
# === 50/4750: Running ObsID 1886 ===
# Starting ObsID 1886 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 1886 already analysed/detected for all windows, skipping
#
# === 51/4750: Running ObsID 2522 ===
# Starting ObsID 2522 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 2522 already analysed/detected for all windows, skipping
#
# === 52/4750: Running ObsID 2537 ===
# Starting ObsID 2537 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 2537 already analysed/detected for all windows, skipping
#
# === 53/4750: Running ObsID 2539 ===
# Starting ObsID 2539 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 2539 already analysed/detected for all windows, skipping
#
# === 54/4750: Running ObsID 2548 ===
# Starting ObsID 2548 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 2548 already analysed/detected for all windows, skipping
#
# === 55/4750: Running ObsID 2549 ===
# Starting ObsID 2549 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 2549 already analysed/detected for all windows, skipping
#
# === 56/4750: Running ObsID 2551 ===
# Starting ObsID 2551 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 2551 already analysed/detected for all windows, skipping
#
# === 57/4750: Running ObsID 2561 ===
# Starting ObsID 2561 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 2561 already analysed/detected for all windows, skipping
#
# === 58/4750: Running ObsID 2562 ===
# Starting ObsID 2562 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 2562 already analysed/detected for all windows, skipping
#
# === 59/4750: Running ObsID 2563 ===
# Starting ObsID 2563 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 2563 already analysed/detected for all windows, skipping
#
# === 60/4750: Running ObsID 2565 ===
# Starting ObsID 2565 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 2565 already analysed/detected for all windows, skipping
#
# === 61/4750: Running ObsID 2579 ===
# Starting ObsID 2579 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 2579 already analysed/detected for all windows, skipping
#
# === 62/4750: Running ObsID 3363 ===
# Starting ObsID 3363 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 3363 already analysed/detected for all windows, skipping
#
# === 63/4750: Running ObsID 3364 ===
# Starting ObsID 3364 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 3364 already analysed/detected for all windows, skipping
#
# === 64/4750: Running ObsID 3498 ===
# Starting ObsID 3498 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 3498 already analysed/detected for all windows, skipping
#
# === 65/4750: Running ObsID 3499 ===
# Starting ObsID 3499 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 3499 already analysed/detected for all windows, skipping
#
# === 66/4750: Running ObsID 3730 ===
# Starting ObsID 3730 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 3730 already analysed/detected for all windows, skipping
#
# === 67/4750: Running ObsID 3744 ===
# Starting ObsID 3744 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 3744 already analysed/detected for all windows, skipping
#
# === 68/4750: Running ObsID 4373 ===
# Starting ObsID 4373 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 4373 already analysed/detected for all windows, skipping
#
# === 69/4750: Running ObsID 4374 ===
# Starting ObsID 4374 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 4374 already analysed/detected for all windows, skipping
#
# === 70/4750: Running ObsID 4395 ===
# Starting ObsID 4395 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 4395 already analysed/detected for all windows, skipping
#
# === 71/4750: Running ObsID 4396 ===
# Starting ObsID 4396 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 4396 already analysed/detected for all windows, skipping
#
# === 72/4750: Running ObsID 3752 ===
# Starting ObsID 3752 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 3752 already analysed/detected for all windows, skipping
#
# === 73/4750: Running ObsID 4472 ===
# Starting ObsID 4472 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 4472 already analysed/detected for all windows, skipping
#
# === 74/4750: Running ObsID 4475 ===
# Starting ObsID 4475 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 4475 already analysed/detected for all windows, skipping
#
# === 75/4750: Running ObsID 4485 ===
# Starting ObsID 4485 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 4485 already analysed/detected for all windows, skipping
#
# === 76/4750: Running ObsID 6171 ===
# Starting ObsID 6171 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 6171 already analysed/detected for all windows, skipping
#
# === 77/4750: Running ObsID 4487 ===
# Starting ObsID 4487 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 4487 already analysed/detected for all windows, skipping
#
# === 78/4750: Running ObsID 4488 ===
# Starting ObsID 4488 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 4488 already analysed/detected for all windows, skipping
#
# === 79/4750: Running ObsID 4489 ===
# Starting ObsID 4489 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 4489 already analysed/detected for all windows, skipping
#
# === 80/4750: Running ObsID 4490 ===
# Starting ObsID 4490 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 4490 already analysed/detected for all windows, skipping
#
# === 81/4750: Running ObsID 4491 ===
# Starting ObsID 4491 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 4491 already analysed/detected for all windows, skipping
#
# === 82/4750: Running ObsID 4497 ===
# Starting ObsID 4497 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 4497 already analysed/detected for all windows, skipping
#
# === 83/4750: Running ObsID 4498 ===
# Starting ObsID 4498 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 4498 already analysed/detected for all windows, skipping
#
# === 84/4750: Running ObsID 4499 ===
# Starting ObsID 4499 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 4499 already analysed/detected for all windows, skipping
#
# === 85/4750: Running ObsID 5381 ===
# Starting ObsID 5381 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 5381 already analysed/detected for all windows, skipping
#
# === 86/4750: Running ObsID 5382 ===
# Starting ObsID 5382 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 5382 already analysed/detected for all windows, skipping
#
# === 87/4750: Running ObsID 5383 ===
# Starting ObsID 5383 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 5383 already analysed/detected for all windows, skipping
#
# === 88/4750: Running ObsID 5384 ===
# Starting ObsID 5384 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 5384 already analysed/detected for all windows, skipping
#
# === 89/4750: Running ObsID 5402 ===
# Starting ObsID 5402 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 5402 already analysed/detected for all windows, skipping
#
# === 90/4750: Running ObsID 5403 ===
# Starting ObsID 5403 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 5403 already analysed/detected for all windows, skipping
#
# === 91/4750: Running ObsID 5404 ===
# Starting ObsID 5404 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 5404 already analysed/detected for all windows, skipping
#
# === 92/4750: Running ObsID 5405 ===
# Starting ObsID 5405 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 5405 already analysed/detected for all windows, skipping
#
# === 93/4750: Running ObsID 5406 ===
# Starting ObsID 5406 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 5406 already analysed/detected for all windows, skipping
#
# === 94/4750: Running ObsID 5415 ===
# Starting ObsID 5415 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 5415 already analysed/detected for all windows, skipping
#
# === 95/4750: Running ObsID 5416 ===
# Starting ObsID 5416 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 5416 already analysed/detected for all windows, skipping
#
# === 96/4750: Running ObsID 5417 ===
# Starting ObsID 5417 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 5417 already analysed/detected for all windows, skipping
#
# === 97/4750: Running ObsID 5418 ===
# Starting ObsID 5418 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 5418 already analysed/detected for all windows, skipping
#
# === 98/4750: Running ObsID 5425 ===
# Starting ObsID 5425 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 5425 already analysed/detected for all windows, skipping
#
# === 99/4750: Running ObsID 5426 ===
# Starting ObsID 5426 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 5426 already analysed/detected for all windows, skipping
#
# === 100/4750: Running ObsID 5427 ===
# Starting ObsID 5427 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 5427 already analysed/detected for all windows, skipping
#
# === 101/4750: Running ObsID 6119 ===
# Starting ObsID 6119 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 6119 already analysed/detected for all windows, skipping
#
# === 102/4750: Running ObsID 6120 ===
# Starting ObsID 6120 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 6120 already analysed/detected for all windows, skipping
#
# === 103/4750: Running ObsID 6121 ===
# Starting ObsID 6121 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 6121 already analysed/detected for all windows, skipping
#
# === 104/4750: Running ObsID 6122 ===
# Starting ObsID 6122 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 6122 already analysed/detected for all windows, skipping
#
# === 105/4750: Running ObsID 6396 ===
# Starting ObsID 6396 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 6396 already analysed/detected for all windows, skipping
#
# === 106/4750: Running ObsID 6409 ===
# Starting ObsID 6409 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 6409 already analysed/detected for all windows, skipping
#
# === 107/4750: Running ObsID 7246 ===
# Starting ObsID 7246 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 7246 already analysed/detected for all windows, skipping
#
# === 108/4750: Running ObsID 7247 ===
# Starting ObsID 7247 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 7247 already analysed/detected for all windows, skipping
#
# === 109/4750: Running ObsID 6412 ===
# Starting ObsID 6412 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 6412 already analysed/detected for all windows, skipping
#
# === 110/4750: Running ObsID 6413 ===
# Starting ObsID 6413 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 6413 already analysed/detected for all windows, skipping
#
# === 111/4750: Running ObsID 6414 ===
# Starting ObsID 6414 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 6414 already analysed/detected for all windows, skipping
#
# === 112/4750: Running ObsID 6415 ===
# Starting ObsID 6415 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 6415 already analysed/detected for all windows, skipping
#
# === 113/4750: Running ObsID 6416 ===
# Starting ObsID 6416 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 6416 already analysed/detected for all windows, skipping
#
# === 114/4750: Running ObsID 6417 ===
# Starting ObsID 6417 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 6417 already analysed/detected for all windows, skipping
#
# === 115/4750: Running ObsID 6418 ===
# Starting ObsID 6418 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 6418 already analysed/detected for all windows, skipping
#
# === 116/4750: Running ObsID 6419 ===
# Starting ObsID 6419 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 6419 already analysed/detected for all windows, skipping
#
# === 117/4750: Running ObsID 6435 ===
# Starting ObsID 6435 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 6435 already analysed/detected for all windows, skipping
#
# === 118/4750: Running ObsID 6436 ===
# Starting ObsID 6436 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 6436 already analysed/detected for all windows, skipping
#
# === 119/4750: Running ObsID 6437 ===
# Starting ObsID 6437 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 6437 already analysed/detected for all windows, skipping
#
# === 120/4750: Running ObsID 6440 ===
# Starting ObsID 6440 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 6440 already analysed/detected for all windows, skipping
#
# === 121/4750: Running ObsID 7417 ===
# Starting ObsID 7417 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 7417 already analysed/detected for all windows, skipping
#
# === 122/4750: Running ObsID 7418 ===
# Starting ObsID 7418 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 7418 already analysed/detected for all windows, skipping
#
# === 123/4750: Running ObsID 7440 ===
# Starting ObsID 7440 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 7440 already analysed/detected for all windows, skipping
#
# === 124/4750: Running ObsID 8571 ===
# Starting ObsID 8571 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 8571 already analysed/detected for all windows, skipping
#
# === 125/4750: Running ObsID 8572 ===
# Starting ObsID 8572 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 8572 already analysed/detected for all windows, skipping
#
# === 126/4750: Running ObsID 8573 ===
# Starting ObsID 8573 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 8573 already analysed/detected for all windows, skipping
#
# === 127/4750: Running ObsID 8574 ===
# Starting ObsID 8574 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 8574 already analysed/detected for all windows, skipping
#
# === 128/4750: Running ObsID 8582 ===
# Starting ObsID 8582 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 8582 already analysed/detected for all windows, skipping
#
# === 129/4750: Running ObsID 8583 ===
# Starting ObsID 8583 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 8583 already analysed/detected for all windows, skipping
#
# === 130/4750: Running ObsID 8584 ===
# Starting ObsID 8584 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 8584 already analysed/detected for all windows, skipping
#
# === 131/4750: Running ObsID 8585 ===
# Starting ObsID 8585 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 8585 already analysed/detected for all windows, skipping
#
# === 132/4750: Running ObsID 10763 ===
# Starting ObsID 10763 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 10763 already analysed/detected for all windows, skipping
#
# === 133/4750: Running ObsID 8900 ===
# Starting ObsID 8900 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 8900 already analysed/detected for all windows, skipping
#
# === 134/4750: Running ObsID 10856 ===
# Starting ObsID 10856 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 10856 already analysed/detected for all windows, skipping
#
# === 135/4750: Running ObsID 8902 ===
# Starting ObsID 8902 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 8902 already analysed/detected for all windows, skipping
#
# === 136/4750: Running ObsID 8903 ===
# Starting ObsID 8903 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 8903 already analysed/detected for all windows, skipping
#
# === 137/4750: Running ObsID 10828 ===
# Starting ObsID 10828 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 10828 already analysed/detected for all windows, skipping
#
# === 138/4750: Running ObsID 8918 ===
# Starting ObsID 8918 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 8918 already analysed/detected for all windows, skipping
#
# === 139/4750: Running ObsID 8921 ===
# Starting ObsID 8921 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 8921 already analysed/detected for all windows, skipping
#
# === 140/4750: Running ObsID 8933 ===
# Starting ObsID 8933 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 8933 already analysed/detected for all windows, skipping
#
# === 141/4750: Running ObsID 8936 ===
# Starting ObsID 8936 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 8936 already analysed/detected for all windows, skipping
#
# === 142/4750: Running ObsID 8942 ===
# Starting ObsID 8942 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 8942 already analysed/detected for all windows, skipping
#
# === 143/4750: Running ObsID 8944 ===
# Starting ObsID 8944 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 8944 already analysed/detected for all windows, skipping
#
# === 144/4750: Running ObsID 9910 ===
# Starting ObsID 9910 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 9910 already analysed/detected for all windows, skipping
#
# === 145/4750: Running ObsID 9915 ===
# Starting ObsID 9915 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 9915 already analysed/detected for all windows, skipping
#
# === 146/4750: Running ObsID 9916 ===
# Starting ObsID 9916 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 9916 already analysed/detected for all windows, skipping
#
# === 147/4750: Running ObsID 9917 ===
# Starting ObsID 9917 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 9917 already analysed/detected for all windows, skipping
#
# === 148/4750: Running ObsID 9922 ===
# Starting ObsID 9922 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 9922 already analysed/detected for all windows, skipping
#
# === 149/4750: Running ObsID 9924 ===
# Starting ObsID 9924 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 9924 already analysed/detected for all windows, skipping
#
# === 150/4750: Running ObsID 9925 ===
# Starting ObsID 9925 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 9925 already analysed/detected for all windows, skipping
#
# === 151/4750: Running ObsID 9926 ===
# Starting ObsID 9926 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 9926 already analysed/detected for all windows, skipping
#
# === 152/4750: Running ObsID 10975 ===
# Starting ObsID 10975 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 10975 already analysed/detected for all windows, skipping
#
# === 153/4750: Running ObsID 10976 ===
# Starting ObsID 10976 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 10976 already analysed/detected for all windows, skipping
#
# === 154/4750: Running ObsID 10977 ===
# Starting ObsID 10977 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 10977 already analysed/detected for all windows, skipping
#
# === 155/4750: Running ObsID 10978 ===
# Starting ObsID 10978 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 10978 already analysed/detected for all windows, skipping
#
# === 156/4750: Running ObsID 10979 ===
# Starting ObsID 10979 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 10979 already analysed/detected for all windows, skipping
#
# === 157/4750: Running ObsID 10984 ===
# Starting ObsID 10984 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 10984 already analysed/detected for all windows, skipping
#
# === 158/4750: Running ObsID 10985 ===
# Starting ObsID 10985 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 10985 already analysed/detected for all windows, skipping
#
# === 159/4750: Running ObsID 10986 ===
# Starting ObsID 10986 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 10986 already analysed/detected for all windows, skipping
#
# === 160/4750: Running ObsID 11978 ===
# Starting ObsID 11978 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 11978 already analysed/detected for all windows, skipping
#
# === 161/4750: Running ObsID 11979 ===
# Starting ObsID 11979 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 11979 already analysed/detected for all windows, skipping
#
# === 162/4750: Running ObsID 11988 ===
# Starting ObsID 11988 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 11988 already analysed/detected for all windows, skipping
#
# === 163/4750: Running ObsID 11989 ===
# Starting ObsID 11989 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 11989 already analysed/detected for all windows, skipping
#
# === 164/4750: Running ObsID 12130 ===
# Starting ObsID 12130 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 12130 already analysed/detected for all windows, skipping
#
# === 165/4750: Running ObsID 12131 ===
# Starting ObsID 12131 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 12131 already analysed/detected for all windows, skipping
#
# === 166/4750: Running ObsID 12134 ===
# Starting ObsID 12134 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 12134 already analysed/detected for all windows, skipping
#
# === 167/4750: Running ObsID 12136 ===
# Starting ObsID 12136 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 12136 already analysed/detected for all windows, skipping
#
# === 168/4750: Running ObsID 12207 ===
# Starting ObsID 12207 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 12207 already analysed/detected for all windows, skipping
#
# === 169/4750: Running ObsID 10991 ===
# Starting ObsID 10991 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 10991 already analysed/detected for all windows, skipping
#
# === 170/4750: Running ObsID 10992 ===
# Starting ObsID 10992 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 10992 already analysed/detected for all windows, skipping
#
# === 171/4750: Running ObsID 10998 ===
# Starting ObsID 10998 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 10998 already analysed/detected for all windows, skipping
#
# === 172/4750: Running ObsID 10999 ===
# Starting ObsID 10999 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 10999 already analysed/detected for all windows, skipping
#
# === 173/4750: Running ObsID 11000 ===
# Starting ObsID 11000 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 11000 already analysed/detected for all windows, skipping
#
# === 174/4750: Running ObsID 11002 ===
# Starting ObsID 11002 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 11002 already analysed/detected for all windows, skipping
#
# === 175/4750: Running ObsID 11009 ===
# Starting ObsID 11009 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 11009 already analysed/detected for all windows, skipping
#
# === 176/4750: Running ObsID 11010 ===
# Starting ObsID 11010 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 11010 already analysed/detected for all windows, skipping
#
# === 177/4750: Running ObsID 11011 ===
# Starting ObsID 11011 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 11011 already analysed/detected for all windows, skipping
#
# === 178/4750: Running ObsID 11016 ===
# Starting ObsID 11016 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 11016 already analysed/detected for all windows, skipping
#
# === 179/4750: Running ObsID 11019 ===
# Starting ObsID 11019 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 11019 already analysed/detected for all windows, skipping
#
# === 180/4750: Running ObsID 11020 ===
# Starting ObsID 11020 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 11020 already analysed/detected for all windows, skipping
#
# === 181/4750: Running ObsID 12335 ===
# Starting ObsID 12335 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 12335 already analysed/detected for all windows, skipping
#
# === 182/4750: Running ObsID 12336 ===
# Starting ObsID 12336 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 12336 already analysed/detected for all windows, skipping
#
# === 183/4750: Running ObsID 12339 ===
# Starting ObsID 12339 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 12339 already analysed/detected for all windows, skipping
#
# === 184/4750: Running ObsID 12355 ===
# Starting ObsID 12355 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 12355 already analysed/detected for all windows, skipping
#
# === 185/4750: Running ObsID 12361 ===
# Starting ObsID 12361 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 12361 already analysed/detected for all windows, skipping
#
# === 186/4750: Running ObsID 12362 ===
# Starting ObsID 12362 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 12362 already analysed/detected for all windows, skipping
#
# === 187/4750: Running ObsID 12371 ===
# Starting ObsID 12371 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 12371 already analysed/detected for all windows, skipping
#
# === 188/4750: Running ObsID 12373 ===
# Starting ObsID 12373 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 12373 already analysed/detected for all windows, skipping
#
# === 189/4750: Running ObsID 12374 ===
# Starting ObsID 12374 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 12374 already analysed/detected for all windows, skipping
#
# === 190/4750: Running ObsID 12381 ===
# Starting ObsID 12381 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 12381 already analysed/detected for all windows, skipping
#
# === 191/4750: Running ObsID 12383 ===
# Starting ObsID 12383 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 12383 already analysed/detected for all windows, skipping
#
# === 192/4750: Running ObsID 12391 ===
# Starting ObsID 12391 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 12391 already analysed/detected for all windows, skipping
#
# === 193/4750: Running ObsID 12392 ===
# Starting ObsID 12392 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 12392 already analysed/detected for all windows, skipping
#
# === 194/4750: Running ObsID 12394 ===
# Starting ObsID 12394 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 12394 already analysed/detected for all windows, skipping
#
# === 195/4750: Running ObsID 13425 ===
# Starting ObsID 13425 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 13425 already analysed/detected for all windows, skipping
#
# === 196/4750: Running ObsID 13426 ===
# Starting ObsID 13426 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 13426 already analysed/detected for all windows, skipping
#
# === 197/4750: Running ObsID 13427 ===
# Starting ObsID 13427 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 13427 already analysed/detected for all windows, skipping
#
# === 198/4750: Running ObsID 13428 ===
# Starting ObsID 13428 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 13428 already analysed/detected for all windows, skipping
#
# === 199/4750: Running ObsID 13429 ===
# Starting ObsID 13429 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 13429 already analysed/detected for all windows, skipping
#
# === 200/4750: Running ObsID 13430 ===
# Starting ObsID 13430 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 13430 already analysed/detected for all windows, skipping
#
# === 201/4750: Running ObsID 13431 ===
# Starting ObsID 13431 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 13431 already analysed/detected for all windows, skipping
#
# === 202/4750: Running ObsID 13432 ===
# Starting ObsID 13432 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 13432 already analysed/detected for all windows, skipping
#
# === 203/4750: Running ObsID 13433 ===
# Starting ObsID 13433 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 13433 already analysed/detected for all windows, skipping
#
# === 204/4750: Running ObsID 13434 ===
# Starting ObsID 13434 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 13434 already analysed/detected for all windows, skipping
#
# === 205/4750: Running ObsID 13604 ===
# Starting ObsID 13604 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 13604 already analysed/detected for all windows, skipping
#
# === 206/4750: Running ObsID 13605 ===
# Starting ObsID 13605 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 13605 already analysed/detected for all windows, skipping
#
# === 207/4750: Running ObsID 13614 ===
# Starting ObsID 13614 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 13614 already analysed/detected for all windows, skipping
#
# === 208/4750: Running ObsID 13615 ===
# Starting ObsID 13615 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 13615 already analysed/detected for all windows, skipping
#
# === 209/4750: Running ObsID 13616 ===
# Starting ObsID 13616 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 13616 already analysed/detected for all windows, skipping
#
# === 210/4750: Running ObsID 13619 ===
# Starting ObsID 13619 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 13619 already analysed/detected for all windows, skipping
#
# === 211/4750: Running ObsID 13625 ===
# Starting ObsID 13625 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 13625 already analysed/detected for all windows, skipping
#
# === 212/4750: Running ObsID 13637 ===
# Starting ObsID 13637 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 13637 already analysed/detected for all windows, skipping
#
# === 213/4750: Running ObsID 13645 ===
# Starting ObsID 13645 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 13645 already analysed/detected for all windows, skipping
#
# === 214/4750: Running ObsID 13649 ===
# Starting ObsID 13649 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 13649 already analysed/detected for all windows, skipping
#
# === 215/4750: Running ObsID 13650 ===
# Starting ObsID 13650 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 13650 already analysed/detected for all windows, skipping
#
# === 216/4750: Running ObsID 14436 ===
# Starting ObsID 14436 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 14436 already analysed/detected for all windows, skipping
#
# === 217/4750: Running ObsID 14444 ===
# Starting ObsID 14444 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 14444 already analysed/detected for all windows, skipping
#
# === 218/4750: Running ObsID 13662 ===
# Starting ObsID 13662 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 13662 already analysed/detected for all windows, skipping
#
# === 219/4750: Running ObsID 13664 ===
# Starting ObsID 13664 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 13664 already analysed/detected for all windows, skipping
#
# === 220/4750: Running ObsID 13668 ===
# Starting ObsID 13668 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 13668 already analysed/detected for all windows, skipping
#
# === 221/4750: Running ObsID 13669 ===
# Starting ObsID 13669 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 13669 already analysed/detected for all windows, skipping
#
# === 222/4750: Running ObsID 14334 ===
# Starting ObsID 14334 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 14334 already analysed/detected for all windows, skipping
#
# === 223/4750: Running ObsID 15546 ===
# Starting ObsID 15546 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 15546 already analysed/detected for all windows, skipping
#
# === 224/4750: Running ObsID 14335 ===
# Starting ObsID 14335 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 14335 already analysed/detected for all windows, skipping
#
# === 225/4750: Running ObsID 14566 ===
# Starting ObsID 14566 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 14566 already analysed/detected for all windows, skipping
#
# === 226/4750: Running ObsID 14576 ===
# Starting ObsID 14576 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 14576 already analysed/detected for all windows, skipping
#
# === 227/4750: Running ObsID 14578 ===
# Starting ObsID 14578 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 14578 already analysed/detected for all windows, skipping
#
# === 228/4750: Running ObsID 14583 ===
# Starting ObsID 14583 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 14583 already analysed/detected for all windows, skipping
#
# === 229/4750: Running ObsID 14602 ===
# Starting ObsID 14602 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 14602 already analysed/detected for all windows, skipping
#
# === 230/4750: Running ObsID 14603 ===
# Starting ObsID 14603 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 14603 already analysed/detected for all windows, skipping
#
# === 231/4750: Running ObsID 14605 ===
# Starting ObsID 14605 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 14605 already analysed/detected for all windows, skipping
#
# === 232/4750: Running ObsID 15597 ===
# Starting ObsID 15597 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 15597 already analysed/detected for all windows, skipping
#
# === 233/4750: Running ObsID 15709 ===
# Starting ObsID 15709 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 15709 already analysed/detected for all windows, skipping
#
# === 234/4750: Running ObsID 15710 ===
# Starting ObsID 15710 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 15710 already analysed/detected for all windows, skipping
#
# === 235/4750: Running ObsID 15712 ===
# Starting ObsID 15712 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 15712 already analysed/detected for all windows, skipping
#
# === 236/4750: Running ObsID 15715 ===
# Starting ObsID 15715 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 15715 already analysed/detected for all windows, skipping
#
# === 237/4750: Running ObsID 15718 ===
# Starting ObsID 15718 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 15718 already analysed/detected for all windows, skipping
#
# === 238/4750: Running ObsID 15727 ===
# Starting ObsID 15727 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 15727 already analysed/detected for all windows, skipping
#
# === 239/4750: Running ObsID 15728 ===
# Starting ObsID 15728 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 15728 already analysed/detected for all windows, skipping
#
# === 240/4750: Running ObsID 16663 ===
# Starting ObsID 16663 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 16663 already analysed/detected for all windows, skipping
#
# === 241/4750: Running ObsID 16664 ===
# Starting ObsID 16664 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 16664 already analysed/detected for all windows, skipping
#
# === 242/4750: Running ObsID 16665 ===
# Starting ObsID 16665 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 16665 already analysed/detected for all windows, skipping
#
# === 243/4750: Running ObsID 17250 ===
# Starting ObsID 17250 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 17250 already analysed/detected for all windows, skipping
#
# === 244/4750: Running ObsID 17251 ===
# Starting ObsID 17251 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 17251 already analysed/detected for all windows, skipping
#
# === 245/4750: Running ObsID 17252 ===
# Starting ObsID 17252 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 17252 already analysed/detected for all windows, skipping
#
# === 246/4750: Running ObsID 17315 ===
# Starting ObsID 17315 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 17315 already analysed/detected for all windows, skipping
#
# === 247/4750: Running ObsID 17316 ===
# Starting ObsID 17316 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 17316 already analysed/detected for all windows, skipping
#
# === 248/4750: Running ObsID 17319 ===
# Starting ObsID 17319 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 17319 already analysed/detected for all windows, skipping
#
# === 249/4750: Running ObsID 17320 ===
# Starting ObsID 17320 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 17320 already analysed/detected for all windows, skipping
#
# === 250/4750: Running ObsID 17735 ===
# Starting ObsID 17735 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 17735 already analysed/detected for all windows, skipping
#
# === 251/4750: Running ObsID 17742 ===
# Starting ObsID 17742 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 17742 already analysed/detected for all windows, skipping
#
# === 252/4750: Running ObsID 19940 ===
# Starting ObsID 19940 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 19940 already analysed/detected for all windows, skipping
#
# === 253/4750: Running ObsID 18915 ===
# Starting ObsID 18915 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 18915 already analysed/detected for all windows, skipping
#
# === 254/4750: Running ObsID 20906 ===
# Starting ObsID 20906 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 20906 already analysed/detected for all windows, skipping
#
# === 255/4750: Running ObsID 18926 ===
# Starting ObsID 18926 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 18926 already analysed/detected for all windows, skipping
#
# === 256/4750: Running ObsID 18927 ===
# Starting ObsID 18927 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 18927 already analysed/detected for all windows, skipping
#
# === 257/4750: Running ObsID 20882 ===
# Starting ObsID 20882 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 20882 already analysed/detected for all windows, skipping
#
# === 258/4750: Running ObsID 20883 ===
# Starting ObsID 20883 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 20883 already analysed/detected for all windows, skipping
#
# === 259/4750: Running ObsID 18943 ===
# Starting ObsID 18943 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 18943 already analysed/detected for all windows, skipping
#
# === 260/4750: Running ObsID 18949 ===
# Starting ObsID 18949 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 18949 already analysed/detected for all windows, skipping
#
# === 261/4750: Running ObsID 18950 ===
# Starting ObsID 18950 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 18950 already analysed/detected for all windows, skipping
#
# === 262/4750: Running ObsID 19709 ===
# Starting ObsID 19709 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 19709 already analysed/detected for all windows, skipping
#
# === 263/4750: Running ObsID 20137 ===
# Starting ObsID 20137 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 20137 already analysed/detected for all windows, skipping
#
# === 264/4750: Running ObsID 20140 ===
# Starting ObsID 20140 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 20140 already analysed/detected for all windows, skipping
#
# === 265/4750: Running ObsID 20150 ===
# Starting ObsID 20150 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 20150 already analysed/detected for all windows, skipping
#
# === 266/4750: Running ObsID 20151 ===
# Starting ObsID 20151 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 20151 already analysed/detected for all windows, skipping
#
# === 267/4750: Running ObsID 20162 ===
# Starting ObsID 20162 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 20162 already analysed/detected for all windows, skipping
#
# === 268/4750: Running ObsID 21071 ===
# Starting ObsID 21071 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 21071 already analysed/detected for all windows, skipping
#
# === 269/4750: Running ObsID 20617 ===
# Starting ObsID 20617 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 20617 already analysed/detected for all windows, skipping
#
# === 270/4750: Running ObsID 20620 ===
# Starting ObsID 20620 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 20620 already analysed/detected for all windows, skipping
#
# === 271/4750: Running ObsID 20621 ===
# Starting ObsID 20621 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 20621 already analysed/detected for all windows, skipping
#
# === 272/4750: Running ObsID 21157 ===
# Starting ObsID 21157 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 21157 already analysed/detected for all windows, skipping
#
# === 273/4750: Running ObsID 21158 ===
# Starting ObsID 21158 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 21158 already analysed/detected for all windows, skipping
#
# === 274/4750: Running ObsID 21174 ===
# Starting ObsID 21174 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 21174 already analysed/detected for all windows, skipping
#
# === 275/4750: Running ObsID 21971 ===
# Starting ObsID 21971 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 21971 already analysed/detected for all windows, skipping
#
# === 276/4750: Running ObsID 21184 ===
# Starting ObsID 21184 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 21184 already analysed/detected for all windows, skipping
#
# === 277/4750: Running ObsID 21186 ===
# Starting ObsID 21186 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 21186 already analysed/detected for all windows, skipping
#
# === 278/4750: Running ObsID 21975 ===
# Starting ObsID 21975 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 21975 already analysed/detected for all windows, skipping
#
# === 279/4750: Running ObsID 21187 ===
# Starting ObsID 21187 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 21187 already analysed/detected for all windows, skipping
#
# === 280/4750: Running ObsID 21193 ===
# Starting ObsID 21193 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 21193 already analysed/detected for all windows, skipping
#
# === 281/4750: Running ObsID 21854 ===
# Starting ObsID 21854 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 21854 already analysed/detected for all windows, skipping
#
# === 282/4750: Running ObsID 21855 ===
# Starting ObsID 21855 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 21855 already analysed/detected for all windows, skipping
#
# === 283/4750: Running ObsID 22303 ===
# Starting ObsID 22303 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 22303 already analysed/detected for all windows, skipping
#
# === 284/4750: Running ObsID 24756 ===
# Starting ObsID 24756 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 24756 already analysed/detected for all windows, skipping
#
# === 285/4750: Running ObsID 22304 ===
# Starting ObsID 22304 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 22304 already analysed/detected for all windows, skipping
#
# === 286/4750: Running ObsID 23255 ===
# Starting ObsID 23255 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 23255 already analysed/detected for all windows, skipping
#
# === 287/4750: Running ObsID 23256 ===
# Starting ObsID 23256 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 23256 already analysed/detected for all windows, skipping
#
# === 288/4750: Running ObsID 22305 ===
# Starting ObsID 22305 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 22305 already analysed/detected for all windows, skipping
#
# === 289/4750: Running ObsID 22306 ===
# Starting ObsID 22306 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 22306 already analysed/detected for all windows, skipping
#
# === 290/4750: Running ObsID 22326 ===
# Starting ObsID 22326 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 22326 already analysed/detected for all windows, skipping
#
# === 291/4750: Running ObsID 22327 ===
# Starting ObsID 22327 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 22327 already analysed/detected for all windows, skipping
#
# === 292/4750: Running ObsID 22328 ===
# Starting ObsID 22328 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 22328 already analysed/detected for all windows, skipping
#
# === 293/4750: Running ObsID 22352 ===
# Starting ObsID 22352 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 22352 already analysed/detected for all windows, skipping
#
# === 294/4750: Running ObsID 22353 ===
# Starting ObsID 22353 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 22353 already analysed/detected for all windows, skipping
#
# === 295/4750: Running ObsID 22354 ===
# Starting ObsID 22354 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 22354 already analysed/detected for all windows, skipping
#
# === 296/4750: Running ObsID 22686 ===
# Starting ObsID 22686 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 22686 already analysed/detected for all windows, skipping
#
# === 297/4750: Running ObsID 23067 ===
# Starting ObsID 23067 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 23067 already analysed/detected for all windows, skipping
#
# === 298/4750: Running ObsID 23275 ===
# Starting ObsID 23275 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 23275 already analysed/detected for all windows, skipping
#
# === 299/4750: Running ObsID 23293 ===
# Starting ObsID 23293 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 23293 already analysed/detected for all windows, skipping
#
# === 300/4750: Running ObsID 23321 ===
# Starting ObsID 23321 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 23321 already analysed/detected for all windows, skipping
#
# === 301/4750: Running ObsID 23354 ===
# Starting ObsID 23354 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 23354 already analysed/detected for all windows, skipping
#
# === 302/4750: Running ObsID 23365 ===
# Starting ObsID 23365 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 23365 already analysed/detected for all windows, skipping
#
# === 303/4750: Running ObsID 23377 ===
# Starting ObsID 23377 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 23377 already analysed/detected for all windows, skipping
#
# === 304/4750: Running ObsID 23379 ===
# Starting ObsID 23379 for windows [0.1, 0.2, 0.4, 0.8]
# 	ObsID 23379 already analysed/detected for all windows, skipping
#
# === 305/4750: Running ObsID 24256 ===
# ...
# 	Finished searching
# 	Searching time: 2 seconds
# 	Window 0.2 ks: 0 new detections
# 	Searching
# search_algorithm.py: 1.3499173298478127 s
# 	Finished searching
# 	Searching time: 1 seconds
# 	Window 0.4 ks: 0 new detections
# 	Searching
# search_algorithm.py: 1.264069588854909 s
# 	Finished searching
# 	Searching time: 1 seconds
# 	Window 0.8 ks: 0 new detections
# 	No detections → deleting new_data/6948
#
# === 3376/4750: Running ObsID 7190 ===
# Starting ObsID 7190 for windows [0.1, 0.2, 0.4, 0.8]
# 	Downloading
# Downloading files for ObsId 7190, total size is 39 Mb.
#
#   Type     Format      Size  0........H.........1  Download Time Average Rate
#   ---------------------------------------------------------------------------
#   evt2     fits       27 Mb  ####################           50 s  559.5 kb/s
#   asol     fits       12 Mb  ####################           16 s  759.5 kb/s
#   bpix     fits       48 Kb  ####################          < 1 s  85.6 kb/s
#   fov      fits        8 Kb  ####################          < 1 s  21.2 kb/s
#   msk      fits        5 Kb  ####################          < 1 s  12.8 kb/s
#
#       Total download size for ObsId 7190 = 39 Mb
#       Total download time for ObsId 7190 = 1 m 7 s
#
# 	Finished downloading
# 	Download time: 80 seconds
# 	Processing
# Running fluximage
# Version: 04 November 2021
#
# Using CSC ACIS broad science energy band.
# Aspect solution pcadf07190_000N001_asol1.fits found.
# Bad-pixel file acisf07190_000N003_bpix1.fits found.
# Mask file secondary/acisf07190_000N003_msk1.fits found.
#
# The output images will have 1746 by 1652 pixels, pixel size of 0.984 arcsec,
#     and cover x=1988.5:5480.5:2,y=3132.5:6436.5:2.
#
# Running tasks in parallel with 128 processors.
# Creating 5 aspect histograms for obsid 7190
# Creating 5 instrument maps for obsid 7190
# Creating 5 exposure maps for obsid 7190
# Combining 5 exposure maps for obsid 7190
# Thresholding data for obsid 7190
# Exposure-correcting image for obsid 7190
#
# The following files were created:
#
#  The clipped counts image is:
#      s3_broad_thresh.img
#
#  The observation FOV is:
#      s3_7190.fov
#
#  The clipped exposure map is:
#      s3_broad_thresh.expmap
#
#  The exposure-corrected image is:
#      s3_broad_flux.img
#
# fluximage: 17.02588951261714 s
# mkpsfmap: 3.4807185092940927 s
# 	Running wavdetect with full scales: 1 2 4 8 16 32
# wavdetect: 19.362307271920145 s
# 	Finished processing
# 	Processing time: 41 seconds
# 	Searching
# search_algorithm.py: 12.990543270949274 s
# 	Finished searching
# 	Searching time: 13 seconds
# 	Window 0.1 ks: 0 new detections
# 	Searching
# search_algorithm.py: 7.187524477019906 s
# 	Finished searching
# 	Searching time: 7 seconds
# 	Window 0.2 ks: 0 new detections
# 	Searching
# search_algorithm.py: 4.359516988042742 s
# 	Finished searching
# 	Searching time: 4 seconds
# 	Window 0.4 ks: 0 new detections
# 	Searching
# search_algorithm.py: 3.0614857370965183 s
# 	Finished searching
# 	Searching time: 3 seconds
# 	Window 0.8 ks: 0 new detections
# 	No detections → deleting new_data/7190
#
# === 3377/4750: Running ObsID 7340 ===
# Starting ObsID 7340 for windows [0.1, 0.2, 0.4, 0.8]
# 	Downloading
# Downloading files for ObsId 7340, total size is 11 Mb.
#
#   Type     Format      Size  0........H.........1  Download Time Average Rate
#   ---------------------------------------------------------------------------
#   evt2     fits        8 Mb  ####################            3 s  2743.4 kb/s
#   asol     fits        3 Mb  ####################           14 s  248.6 kb/s
#   bpix     fits       23 Kb  ####################          < 1 s  49.2 kb/s
#   fov      fits        8 Kb  ####################          < 1 s  20.1 kb/s
#   msk      fits        5 Kb  ####################          < 1 s  12.7 kb/s
#
#       Total download size for ObsId 7340 = 11 Mb
#       Total download time for ObsId 7340 = 18 s
#
# 	Finished downloading
# 	Download time: 24 seconds
# 	Processing
# Running fluximage
# Version: 04 November 2021
#
# Using CSC ACIS broad science energy band.
# Aspect solution pcadf07340_000N001_asol1.fits found.
# Bad-pixel file acisf07340_000N003_bpix1.fits found.
# Mask file secondary/acisf07340_000N003_msk1.fits found.
#
# The output images will have 1745 by 1652 pixels, pixel size of 0.984 arcsec,
#     and cover x=1988.5:5478.5:2,y=3132.5:6436.5:2.
#
# Running tasks in parallel with 128 processors.
# Creating 5 aspect histograms for obsid 7340
# Creating 5 instrument maps for obsid 7340
# Creating 5 exposure maps for obsid 7340
# Combining 5 exposure maps for obsid 7340
# Thresholding data for obsid 7340
# Exposure-correcting image for obsid 7340
#
# The following files were created:
#
#  The clipped counts image is:
#      s3_broad_thresh.img
#
#  The observation FOV is:
#      s3_7340.fov
#
#  The clipped exposure map is:
#      s3_broad_thresh.expmap
#
#  The exposure-corrected image is:
#      s3_broad_flux.img
#
# fluximage: 15.083270162343979 s
# mkpsfmap: 3.295264554210007 s
# 	Running wavdetect with full scales: 1 2 4 8 16 32
# wavdetect: 19.80052791768685 s
# 	Finished processing
# 	Processing time: 39 seconds
# 	Searching
# search_algorithm.py: 3.1114060739055276 s
# 	Finished searching
# 	Searching time: 3 seconds
# 	Window 0.1 ks: 0 new detections
# 	Searching
# search_algorithm.py: 2.104880923870951 s
# 	Finished searching
# 	Searching time: 2 seconds
# 	Window 0.2 ks: 0 new detections
# 	Searching
# search_algorithm.py: 1.6340987239964306 s
# 	Finished searching
# 	Searching time: 2 seconds
# 	Window 0.4 ks: 0 new detections
# 	Searching
# search_algorithm.py: 1.3917772429995239 s
# 	Finished searching
# 	Searching time: 1 seconds
# 	Window 0.8 ks: 0 new detections
# 	No detections → deleting new_data/7340
#
# === 3378/4750: Running ObsID 6950 ===
# Starting ObsID 6950 for windows [0.1, 0.2, 0.4, 0.8]
# 	Downloading
# Downloading files for ObsId 6950, total size is 5 Mb.
#
#   Type     Format      Size  0........H.........1  Download Time Average Rate
#   ---------------------------------------------------------------------------
#   asol     fits        3 Mb  ####################            6 s  594.5 kb/s
#   evt2     fits        2 Mb  ####################            3 s  675.5 kb/s
#   bpix     fits       32 Kb  ####################          < 1 s  67.5 kb/s
#   fov      fits        8 Kb  ####################          < 1 s  21.3 kb/s
#   msk      fits        5 Kb  ####################          < 1 s  13.1 kb/s
#
#       Total download size for ObsId 6950 = 5 Mb
#       Total download time for ObsId 6950 = 10 s
#
# 	Finished downloading
# 	Download time: 15 seconds
# 	Processing
# Running fluximage
# Version: 04 November 2021
#
# Using CSC ACIS broad science energy band.
# Aspect solution pcadf06950_000N001_asol1.fits found.
# Bad-pixel file acisf06950_000N003_bpix1.fits found.
# Mask file secondary/acisf06950_000N003_msk1.fits found.
#
# The output images will have 1827 by 1145 pixels, pixel size of 0.984 arcsec,
#     and cover x=2906.5:6560.5:2,y=2988.5:5278.5:2.
#
# Running tasks in parallel with 128 processors.
# Creating 5 aspect histograms for obsid 6950
# Creating 5 instrument maps for obsid 6950
# Creating 5 exposure maps for obsid 6950
# Combining 5 exposure maps for obsid 6950
# Thresholding data for obsid 6950
# Exposure-correcting image for obsid 6950
#
# The following files were created:
#
#  The clipped counts image is:
#      s3_broad_thresh.img
#
#  The observation FOV is:
#      s3_6950.fov
#
#  The clipped exposure map is:
#      s3_broad_thresh.expmap
#
#  The exposure-corrected image is:
#      s3_broad_flux.img
#
# fluximage: 12.782382627949119 s
# mkpsfmap: 2.813633352983743 s
# 	Running wavdetect with full scales: 1 2 4 8 16 32
# wavdetect: 14.884115922730416 s
# 	Finished processing
# 	Processing time: 31 seconds
# 	Searching
# search_algorithm.py: 3.816907525062561 s
# 	Finished searching
# 	Searching time: 4 seconds
# 	Window 0.1 ks: 0 new detections
# 	Searching
# search_algorithm.py: 2.369480798020959 s
# 	Finished searching
# 	Searching time: 2 seconds
# 	Window 0.2 ks: 0 new detections
# 	Searching
# search_algorithm.py: 1.846179184038192 s
# 	Finished searching
# 	Searching time: 2 seconds
# 	Window 0.4 ks: 0 new detections
# 	Searching
# search_algorithm.py: 1.8446153029799461 s
# 	Finished searching
# 	Searching time: 2 seconds
# 	Window 0.8 ks: 0 new detections
# 	No detections → deleting new_data/6950
#
# === 3379/4750: Running ObsID 7374 ===
# Starting ObsID 7374 for windows [0.1, 0.2, 0.4, 0.8]
# 	Downloading
# Downloading files for ObsId 7374, total size is 9 Mb.
#
#   Type     Format      Size  0........H.........1  Download Time Average Rate
#   ---------------------------------------------------------------------------
#   asol     fits        5 Mb  ####################            9 s  643.0 kb/s
#   evt2     fits        3 Mb  ####################            6 s  576.8 kb/s
#   bpix     fits       44 Kb  ####################          < 1 s  77.0 kb/s
#   fov      fits        8 Kb  ####################          < 1 s  21.4 kb/s
#   msk      fits        5 Kb  ####################          < 1 s  13.3 kb/s
#
#       Total download size for ObsId 7374 = 9 Mb
#       Total download time for ObsId 7374 = 16 s
#
# 	Finished downloading
# 	Download time: 21 seconds
# 	Processing
# Running fluximage
# Version: 04 November 2021
#
# Using CSC ACIS broad science energy band.
# Aspect solution pcadf07374_000N001_asol1.fits found.
# Bad-pixel file acisf07374_000N003_bpix1.fits found.
# Mask file secondary/acisf07374_000N003_msk1.fits found.
#
# The output images will have 1826 by 1137 pixels, pixel size of 0.984 arcsec,
#     and cover x=2908.5:6560.5:2,y=3004.5:5278.5:2.
#
# Running tasks in parallel with 128 processors.
# Creating 5 aspect histograms for obsid 7374
# Creating 5 instrument maps for obsid 7374
# Creating 5 exposure maps for obsid 7374
# Combining 5 exposure maps for obsid 7374
# Thresholding data for obsid 7374
# Exposure-correcting image for obsid 7374
#
# The following files were created:
#
#  The clipped counts image is:
#      s3_broad_thresh.img
#
#  The observation FOV is:
#      s3_7374.fov
#
#  The clipped exposure map is:
#      s3_broad_thresh.expmap
#
#  The exposure-corrected image is:
#      s3_broad_flux.img
#
# fluximage: 13.577522634994239 s
# mkpsfmap: 2.751924960874021 s
# 	Running wavdetect with full scales: 1 2 4 8 16 32
# wavdetect: 15.003660605754703 s
# 	Finished processing
# 	Processing time: 32 seconds
# 	Searching
# search_algorithm.py: 7.2868823749013245 s
# 	Finished searching
# 	Searching time: 7 seconds
# 	Window 0.1 ks: 0 new detections
# 	Searching
# search_algorithm.py: 4.339547378011048 s
# 	Finished searching
# 	Searching time: 4 seconds
# 	Window 0.2 ks: 0 new detections
# 	Searching
# search_algorithm.py: 2.5897367605939507 s
# 	Finished searching
# 	Searching time: 3 seconds
# 	Window 0.4 ks: 0 new detections
# 	Searching
# search_algorithm.py: 1.946730012074113 s
# 	Finished searching
# 	Searching time: 2 seconds
# 	Window 0.8 ks: 0 new detections
# 	No detections → deleting new_data/7374
#
# === 3380/4750: Running ObsID 6951 ===
# Starting ObsID 6951 for windows [0.1, 0.2, 0.4, 0.8]
# 	Downloading
# Downloading files for ObsId 6951, total size is 13 Mb.
#
#   Type     Format      Size  0........H.........1  Download Time Average Rate
#   ---------------------------------------------------------------------------
#   evt2     fits        7 Mb  ####################           16 s  468.0 kb/s
#   asol     fits        6 Mb  ####################            7 s  833.9 kb/s
#   bpix     fits       46 Kb  ####################          < 1 s  79.7 kb/s
#   fov      fits        7 Kb  ####################          < 1 s  19.0 kb/s
#   msk      fits        5 Kb  ####################          < 1 s  13.2 kb/s
#
#       Total download size for ObsId 6951 = 13 Mb
#       Total download time for ObsId 6951 = 25 s
#
# 	Finished downloading
# 	Download time: 31 seconds
# 	Processing
# Running fluximage
# Version: 04 November 2021
#
# Using CSC ACIS broad science energy band.
# Aspect solution pcadf06951_000N001_asol1.fits found.
# Bad-pixel file acisf06951_000N003_bpix1.fits found.
# Mask file secondary/acisf06951_000N003_msk1.fits found.
#
# The output images will have 2152 by 1596 pixels, pixel size of 0.984 arcsec,
#     and cover x=2776.5:7080.5:2,y=2310.5:5502.5:2.
#
# Running tasks in parallel with 128 processors.
# Creating 5 aspect histograms for obsid 6951
# Creating 5 instrument maps for obsid 6951
# Creating 5 exposure maps for obsid 6951
# Combining 5 exposure maps for obsid 6951
# Thresholding data for obsid 6951
# Exposure-correcting image for obsid 6951
#
# The following files were created:
#
#  The clipped counts image is:
#      s3_broad_thresh.img
#
#  The observation FOV is:
#      s3_6951.fov
#
#  The clipped exposure map is:
#      s3_broad_thresh.expmap
#
#  The exposure-corrected image is:
#      s3_broad_flux.img
#
# fluximage: 16.269669585861266 s
# mkpsfmap: 3.279391872230917 s
# 	Running wavdetect with full scales: 1 2 4 8 16 32
# wavdetect: 23.952759854029864 s
# 	Finished processing
# 	Processing time: 44 seconds
# 	Searching
# search_algorithm.py: 7.56684791110456 s
# 	Finished searching
# 	Searching time: 8 seconds
# 	Window 0.1 ks: 0 new detections
# 	Searching
# search_algorithm.py: 4.464599905069917 s
# 	Finished searching
# 	Searching time: 4 seconds
# 	Window 0.2 ks: 0 new detections
# 	Searching
# search_algorithm.py: 3.154585673008114 s
# 	Finished searching
# 	Searching time: 3 seconds
# 	Window 0.4 ks: 0 new detections
# 	Searching
# search_algorithm.py: 2.06541834725067 s
# 	Finished searching
# 	Searching time: 2 seconds
# 	Window 0.8 ks: 0 new detections
# 	No detections → deleting new_data/6951
#
# === 3381/4750: Running ObsID 6952 ===
# Starting ObsID 6952 for windows [0.1, 0.2, 0.4, 0.8]
# 	Downloading
# Downloading files for ObsId 6952, total size is 6 Mb.
#
#   Type     Format      Size  0........H.........1  Download Time Average Rate
#   ---------------------------------------------------------------------------
#   asol     fits        4 Mb  ####################            7 s  541.8 kb/s
#   evt2     fits        2 Mb  ####################            3 s  678.6 kb/s
#   bpix     fits       35 Kb  ####################          < 1 s  68.8 kb/s
#   fov      fits        8 Kb  ####################          < 1 s  11.6 kb/s
#   msk      fits        5 Kb  ####################          < 1 s  12.9 kb/s
#
#       Total download size for ObsId 6952 = 6 Mb
#       Total download time for ObsId 6952 = 12 s
#
# 	Finished downloading
# 	Download time: 17 seconds
# 	Processing
# Running fluximage
# Version: 04 November 2021
#
# Using CSC ACIS broad science energy band.
# Aspect solution pcadf06952_000N001_asol1.fits found.
# Bad-pixel file acisf06952_000N003_bpix1.fits found.
# Mask file secondary/acisf06952_000N003_msk1.fits found.
#
# The output images will have 1580 by 1780 pixels, pixel size of 0.984 arcsec,
#     and cover x=2814.5:5974.5:2,y=1894.5:5454.5:2.
#
# Running tasks in parallel with 128 processors.
# Creating 5 aspect histograms for obsid 6952
# Creating 5 instrument maps for obsid 6952
# Creating 5 exposure maps for obsid 6952
# Combining 5 exposure maps for obsid 6952
# Thresholding data for obsid 6952
# Exposure-correcting image for obsid 6952
#
# The following files were created:
#
#  The clipped counts image is:
#      s3_broad_thresh.img
#
#  The observation FOV is:
#      s3_6952.fov
#
#  The clipped exposure map is:
#      s3_broad_thresh.expmap
#
#  The exposure-corrected image is:
#      s3_broad_flux.img
#
# fluximage: 15.124194098170847 s
# mkpsfmap: 3.126774901058525 s
# 	Running wavdetect with full scales: 1 2 4 8 16 32
# wavdetect: 19.583306189160794 s
# 	Finished processing
# 	Processing time: 38 seconds
# 	Searching
# search_algorithm.py: 5.205440069083124 s
# 	Finished searching
# 	Searching time: 5 seconds
# 	Window 0.1 ks: 0 new detections
# 	Searching
# search_algorithm.py: 3.076921522151679 s
# 	Finished searching
# 	Searching time: 3 seconds
# 	Window 0.2 ks: 0 new detections
# 	Searching
# search_algorithm.py: 2.0950820725411177 s
# 	Finished searching
# 	Searching time: 2 seconds
# 	Window 0.4 ks: 0 new detections
# 	Searching
# search_algorithm.py: 1.599925249349326 s
# 	Finished searching
# 	Searching time: 2 seconds
# 	Window 0.8 ks: 0 new detections
# 	No detections → deleting new_data/6952
#
# === 3382/4750: Running ObsID 6953 ===
# Starting ObsID 6953 for windows [0.1, 0.2, 0.4, 0.8]
# 	Downloading
# Downloading files for ObsId 6953, total size is 7 Mb.
#
#   Type     Format      Size  0........H.........1  Download Time Average Rate
#   ---------------------------------------------------------------------------
#   asol     fits        4 Mb  ########
